# %% [markdown]
# <a href="https://colab.research.google.com/github/Kaifjamadar/Internship/blob/main/Task_2/Copy_of_Barchart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("/content/drive/MyDrive/Dataset/ign_scores.csv")
a=df['Platform']
b=df['Action']
x=plt.bar(a,b)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("/content/drive/MyDrive/Dataset/museum_visitors.csv")
x=df['Avila Adobe']
y=df['Date']
z=plt.bar(x,y)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("/content/drive/MyDrive/Dataset/cancer_m.csv")
x=df['Texture (mean)']
y=df['Id']
z=plt.bar(x,y)
plt.show()

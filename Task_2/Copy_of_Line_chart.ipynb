# %% [markdown]
# <a href="https://colab.research.google.com/github/Kaifjamadar/Internship/blob/main/Task_2/Copy_of_Line_chart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/Dataset/candy.csv')
x=df['id']
y=df['caramel']
plt.plot(x,y)

# %%
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/Dataset/insurance.csv')
a=df['age']
b=df['bmi']
plt.plot(a,b)

# %%
import matplotlib.pyplot as plt
import plotly.express as px
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/Dataset/iris_virginica.csv')
x=df['Id']
y=df['Species']
plt.plot(x,y)
